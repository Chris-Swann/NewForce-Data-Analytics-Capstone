# %%
import pandas as pd

# %%
master = pd.read_csv('../data/master/all_races_combined_master.csv', low_memory = False)

# %%
print(master.dtypes)
# Out:
# Series_ID         int64
# Race_ID           int64
# Date             object
# Year              int64
# Rank             object
# Status           object
# Name             object
# City             object
# State            object
# Age             float64
# Gender           object
# Gender_Rank     float64
# Time             object
# Race             object
# Race_Loc         object
# Race_Dist        object
# Age_Category     object
# Nationality      object
# dtype: object

# %%
master.head()
# Out:
#    Series_ID  Race_ID                       Date  Year Rank    Status  \
# 0      50001       22  Saturday, January 8, 2022  2022  1.0  Finisher
# 1      50001       22  Saturday, January 8, 2022  2022  2.0  Finisher
# 2      50001       22  Saturday, January 8, 2022  2022  3.0  Finisher
# 3      50001       22  Saturday, January 8, 2022  2022  4.0  Finisher
# 4      50001       22  Saturday, January 8, 2022  2022  5.0  Finisher
#
#                 Name            City State   Age Gender  Gender_Rank     Time  \
# 0       jonathan rea         Boulder    CO  29.0      M          1.0  8:10:00
# 1          tyler fox          Lander    WY  29.0      M          2.0  8:14:53
# 2  joseph mcconaughy         Seattle    WA  30.0      M          3.0  8:17:34
# 3        rod farvard   Mammoth Lakes    CA  26.0      M          4.0  8:28:39
# 4         jimmy elam  Salt Lake City    UT  34.0      M          5.0  8:33:07
#
#            Race     Race_Loc Race_Dist Age_Category Nationality
# ...

# %%
master.drop(columns=['City', 'State'], inplace=True)

# %%
master.head()
# Out:
#    Series_ID  Race_ID                       Date  Year Rank    Status  \
# 0      50001       22  Saturday, January 8, 2022  2022  1.0  Finisher
# 1      50001       22  Saturday, January 8, 2022  2022  2.0  Finisher
# 2      50001       22  Saturday, January 8, 2022  2022  3.0  Finisher
# 3      50001       22  Saturday, January 8, 2022  2022  4.0  Finisher
# 4      50001       22  Saturday, January 8, 2022  2022  5.0  Finisher
#
#                 Name   Age Gender  Gender_Rank     Time          Race  \
# 0       jonathan rea  29.0      M          1.0  8:10:00  Bandera 100k
# 1          tyler fox  29.0      M          2.0  8:14:53  Bandera 100k
# 2  joseph mcconaughy  30.0      M          3.0  8:17:34  Bandera 100k
# 3        rod farvard  26.0      M          4.0  8:28:39  Bandera 100k
# 4         jimmy elam  34.0      M          5.0  8:33:07  Bandera 100k
#
#       Race_Loc Race_Dist Age_Category Nationality
# 0  Bandera, TX      100K        20-34         USA
# ...

# %%
master.shape
# Out:
# (71095, 16)

# %%
print(master.dtypes)
# Out:
# Series_ID         int64
# Race_ID           int64
# Date             object
# Year              int64
# Rank             object
# Status           object
# Name             object
# Age             float64
# Gender           object
# Gender_Rank     float64
# Time             object
# Race             object
# Race_Loc         object
# Race_Dist        object
# Age_Category     object
# Nationality      object
# dtype: object

# %%
master['Date'] = pd.to_datetime(master['Date'], errors='coerce')
master['Status'] = master['Status'].astype('category')
master['Gender'] = master['Gender'].astype('category')
master['Age_Category'] = master['Age_Category'].astype('category')
master['Nationality'] = master['Nationality'].astype('category')

# %%
master.head()
# Out:
#    Series_ID  Race_ID       Date  Year Rank    Status               Name  \
# 0      50001       22 2022-01-08  2022  1.0  Finisher       jonathan rea
# 1      50001       22 2022-01-08  2022  2.0  Finisher          tyler fox
# 2      50001       22 2022-01-08  2022  3.0  Finisher  joseph mcconaughy
# 3      50001       22 2022-01-08  2022  4.0  Finisher        rod farvard
# 4      50001       22 2022-01-08  2022  5.0  Finisher         jimmy elam
#
#     Age Gender  Gender_Rank     Time          Race     Race_Loc Race_Dist  \
# 0  29.0      M          1.0  8:10:00  Bandera 100k  Bandera, TX      100K
# 1  29.0      M          2.0  8:14:53  Bandera 100k  Bandera, TX      100K
# 2  30.0      M          3.0  8:17:34  Bandera 100k  Bandera, TX      100K
# 3  26.0      M          4.0  8:28:39  Bandera 100k  Bandera, TX      100K
# 4  34.0      M          5.0  8:33:07  Bandera 100k  Bandera, TX      100K
#
#   Age_Category Nationality
# 0        20-34         USA
# ...

# %%
def clean_rank_column(col):
    return pd.to_numeric(master[col], errors='coerce').astype('Int64').combine_first(master[col])

master['Rank'] = clean_rank_column('Rank')
master['Gender_Rank'] = clean_rank_column('Gender_Rank')

# %%
master.head()
# Out:
#    Series_ID  Race_ID       Date  Year Rank    Status               Name  \
# 0      50001       22 2022-01-08  2022    1  Finisher       jonathan rea
# 1      50001       22 2022-01-08  2022    2  Finisher          tyler fox
# 2      50001       22 2022-01-08  2022    3  Finisher  joseph mcconaughy
# 3      50001       22 2022-01-08  2022    4  Finisher        rod farvard
# 4      50001       22 2022-01-08  2022    5  Finisher         jimmy elam
#
#     Age Gender  Gender_Rank     Time          Race     Race_Loc Race_Dist  \
# 0  29.0      M          1.0  8:10:00  Bandera 100k  Bandera, TX      100K
# 1  29.0      M          2.0  8:14:53  Bandera 100k  Bandera, TX      100K
# 2  30.0      M          3.0  8:17:34  Bandera 100k  Bandera, TX      100K
# 3  26.0      M          4.0  8:28:39  Bandera 100k  Bandera, TX      100K
# 4  34.0      M          5.0  8:33:07  Bandera 100k  Bandera, TX      100K
#
#   Age_Category Nationality
# 0        20-34         USA
# ...

# %%
master['Gender_Rank'] = pd.to_numeric(master['Gender_Rank'], errors='coerce')
master['Gender_Rank'] = master['Gender_Rank'].astype('Int64')

# %%
master.head()
# Out:
#    Series_ID  Race_ID       Date  Year Rank    Status               Name  \
# 0      50001       22 2022-01-08  2022    1  Finisher       jonathan rea
# 1      50001       22 2022-01-08  2022    2  Finisher          tyler fox
# 2      50001       22 2022-01-08  2022    3  Finisher  joseph mcconaughy
# 3      50001       22 2022-01-08  2022    4  Finisher        rod farvard
# 4      50001       22 2022-01-08  2022    5  Finisher         jimmy elam
#
#     Age Gender  Gender_Rank     Time          Race     Race_Loc Race_Dist  \
# 0  29.0      M            1  8:10:00  Bandera 100k  Bandera, TX      100K
# 1  29.0      M            2  8:14:53  Bandera 100k  Bandera, TX      100K
# 2  30.0      M            3  8:17:34  Bandera 100k  Bandera, TX      100K
# 3  26.0      M            4  8:28:39  Bandera 100k  Bandera, TX      100K
# 4  34.0      M            5  8:33:07  Bandera 100k  Bandera, TX      100K
#
#   Age_Category Nationality
# 0        20-34         USA
# ...

# %%
master.drop(columns=['Age'], inplace=True)

# %%
master.head()
# Out:
#    Series_ID  Race_ID       Date  Year Rank    Status               Name  \
# 0      50001       22 2022-01-08  2022    1  Finisher       jonathan rea
# 1      50001       22 2022-01-08  2022    2  Finisher          tyler fox
# 2      50001       22 2022-01-08  2022    3  Finisher  joseph mcconaughy
# 3      50001       22 2022-01-08  2022    4  Finisher        rod farvard
# 4      50001       22 2022-01-08  2022    5  Finisher         jimmy elam
#
#   Gender  Gender_Rank     Time          Race     Race_Loc Race_Dist  \
# 0      M            1  8:10:00  Bandera 100k  Bandera, TX      100K
# 1      M            2  8:14:53  Bandera 100k  Bandera, TX      100K
# 2      M            3  8:17:34  Bandera 100k  Bandera, TX      100K
# 3      M            4  8:28:39  Bandera 100k  Bandera, TX      100K
# 4      M            5  8:33:07  Bandera 100k  Bandera, TX      100K
#
#   Age_Category Nationality
# 0        20-34         USA
# 1        20-34         USA
# 2        20-34         USA
# ...

# %%
master.to_csv('../data/master/all_races_combined_master.csv', index = False, encoding = 'utf-8')

# %%
master['Date'] = pd.to_datetime(master['Date'], errors='coerce', infer_datetime_format=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18760\2376945378.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   master['Date'] = pd.to_datetime(master['Date'], errors='coerce', infer_datetime_format=True)

# %%
master
# Out:
#        Series_ID  Race_ID       Date  Year Rank    Status  \
# 0          50001       22 2022-01-08  2022    1  Finisher
# 1          50001       22 2022-01-08  2022    2  Finisher
# 2          50001       22 2022-01-08  2022    3  Finisher
# 3          50001       22 2022-01-08  2022    4  Finisher
# 4          50001       22 2022-01-08  2022    5  Finisher
# ...          ...      ...        ...   ...  ...       ...
# 71090        142    14225        NaT  2025  DNF       DNF
# 71091        142    14225        NaT  2025  DNF       DNF
# 71092        142    14225        NaT  2025  DNF       DNF
# 71093        142    14225        NaT  2025  DNF       DNF
# 71094        142    14225        NaT  2025  DNF       DNF
#
#                          Name Gender  Gender_Rank     Time  \
# 0                jonathan rea      M            1  8:10:00
# 1                   tyler fox      M            2  8:14:53
# 2           joseph mcconaughy      M            3  8:17:34
# ...

# %%
race_id = pd.read_csv('../data/master/race_ids_master.csv')

# %%
df1 = pd.read_csv('../data/combined/utmb_format_master_df.csv')
df2 = pd.read_csv('../data/combined/ultrasignup_combined_df_v2.csv')

# %%
master_combined = pd.concat([df1, df2], ignore_index=True)

# %%
print(master_combined['Date'].unique())
# Out:
# ['September 1, 2017' 'August 31, 2018' 'August 30, 2019' 'August 27, 2021'
#  'August 26, 2022' 'September 1, 2023' 'August 30, 2024' 'August 29, 2025'
#  'December 9th, 2022' 'December 8th, 2023' 'December 6th, 2024'
#  'September 23, 2023' 'September 20, 2024' 'September 19, 2025'
#  'September 30, 2023' 'October 4, 2024' 'September 27, 2025'
#  'February 8, 2020' 'February 13, 2021' 'February 11, 2023'
#  'February 17, 2024' 'February 15, 2025' 'April 28, 2018' 'April 27, 2019'
#  'April 24, 2021' 'April 23, 2022' 'April 28, 2023' 'April 26, 2024'
#  'April 25, 2025' 'March 23, 2024' 'March 22, 2025' 'August 31, 2017'
#  'January 8, 2022' 'January 7, 2023' 'January 13, 2024' 'January 11, 2025'
#  'February 15, 2014' 'February 14, 2015' 'February 13, 2016'
#  'February 18, 2017' 'February 17, 2018' 'February 16, 2019'
#  'February 15, 2020' 'February 12, 2022' 'February 18, 2023'
#  'February 10, 2024' 'February 8, 2025' 'Nov 12, 2011' 'Oct 27, 2012'
# ...

# %%
master_combined.drop_duplicates(inplace=True)
master_combined.sort_values(by='Date', inplace=True)

# %%
master_combined.shape
# Out:
# (71080, 15)

# %%
master_combined
# Out:
#        Series_ID  Race_ID                Date  Year Rank    Status  \
# 27220       3753    37542      April 23, 2022  2022  DNF       DNF
# 26861       3753    37542      April 23, 2022  2022  119  Finisher
# 26862       3753    37542      April 23, 2022  2022  120  Finisher
# 26863       3753    37542      April 23, 2022  2022  121  Finisher
# 26864       3753    37542      April 23, 2022  2022  122  Finisher
# ...          ...      ...                 ...   ...  ...       ...
# 19979      32444    23444  September 30, 2023  2023  621  Finisher
# 19978      32444    23444  September 30, 2023  2023  621  Finisher
# 19977      32444    23444  September 30, 2023  2023  620  Finisher
# 19989      32444    23444  September 30, 2023  2023  632  Finisher
# 19411      32444    23444  September 30, 2023  2023   54  Finisher
#
#                       Name Nationality Gender  Gender_Rank Age_Category  \
# 27220       jasha reynolds         USA      M          NaN        45-49
# ...

# %%
master_combined['Status'] = master_combined['Status'].astype('category')
master_combined['Gender'] = master_combined['Gender'].astype('category')
master_combined['Age_Category'] = master_combined['Age_Category'].astype('category')
master_combined['Nationality'] = master_combined['Nationality'].astype('category')

# %%
master_combined.reset_index(drop = True)
# Out:
#        Series_ID  Race_ID                Date  Year Rank    Status  \
# 0           3753    37542      April 23, 2022  2022  DNF       DNF
# 1           3753    37542      April 23, 2022  2022  119  Finisher
# 2           3753    37542      April 23, 2022  2022  120  Finisher
# 3           3753    37542      April 23, 2022  2022  121  Finisher
# 4           3753    37542      April 23, 2022  2022  122  Finisher
# ...          ...      ...                 ...   ...  ...       ...
# 71075      32444    23444  September 30, 2023  2023  621  Finisher
# 71076      32444    23444  September 30, 2023  2023  621  Finisher
# 71077      32444    23444  September 30, 2023  2023  620  Finisher
# 71078      32444    23444  September 30, 2023  2023  632  Finisher
# 71079      32444    23444  September 30, 2023  2023   54  Finisher
#
#                       Name Nationality Gender  Gender_Rank Age_Category  \
# 0           jasha reynolds         USA      M          NaN        45-49
# ...

# %%
master_combined['Gender_Rank'] = master_combined['Gender_Rank'].apply(lambda x: int(x) if pd.notnull(x) else x)

# %%
master_combined['Gender_Rank'] = master_combined['Gender_Rank'].astype('Int64')

# %%
master_combined['Time'] = pd.to_timedelta(master_combined['Time'], errors='coerce')

# %%
print(master_combined.dtypes)
# Out:
# Series_ID                 int64
# Race_ID                   int64
# Date                     object
# Year                      int64
# Rank                     object
# Status                 category
# Name                     object
# Nationality            category
# Gender                 category
# Gender_Rank               Int64
# Age_Category           category
# Time            timedelta64[ns]
# Race                     object
# Race_Loc                 object
# Race_Dist                object
# dtype: object

# %%
master_combined
# Out:
#        Series_ID  Race_ID                Date  Year Rank    Status  \
# 27220       3753    37542      April 23, 2022  2022  DNF       DNF
# 26861       3753    37542      April 23, 2022  2022  119  Finisher
# 26862       3753    37542      April 23, 2022  2022  120  Finisher
# 26863       3753    37542      April 23, 2022  2022  121  Finisher
# 26864       3753    37542      April 23, 2022  2022  122  Finisher
# ...          ...      ...                 ...   ...  ...       ...
# 19979      32444    23444  September 30, 2023  2023  621  Finisher
# 19978      32444    23444  September 30, 2023  2023  621  Finisher
# 19977      32444    23444  September 30, 2023  2023  620  Finisher
# 19989      32444    23444  September 30, 2023  2023  632  Finisher
# 19411      32444    23444  September 30, 2023  2023   54  Finisher
#
#                       Name Nationality Gender  Gender_Rank Age_Category  \
# 27220       jasha reynolds         USA      M         <NA>        45-49
# ...

# %%
failed_dates = master_combined[master_combined['Date'].isna()]
print(failed_dates[['Date', 'Race', 'Race_ID']])
# Out:
# Empty DataFrame
# Columns: [Date, Race, Race_ID]
# Index: []

# %%
# master_combined.to_csv('../data/master/all_races_combined_master.csv', index = False, encoding = 'utf-8')

# %%
# Filter to keep only rows from 2021 onward
combined_2021_2025 = master_combined[master_combined["Date"] >= "2021-01-01"]

# %%
combined_2021_2025
# Out:
#        Series_ID  Race_ID                Date  Year Rank    Status  \
# 27220       3753    37542      April 23, 2022  2022  DNF       DNF
# 26861       3753    37542      April 23, 2022  2022  119  Finisher
# 26862       3753    37542      April 23, 2022  2022  120  Finisher
# 26863       3753    37542      April 23, 2022  2022  121  Finisher
# 26864       3753    37542      April 23, 2022  2022  122  Finisher
# ...          ...      ...                 ...   ...  ...       ...
# 19979      32444    23444  September 30, 2023  2023  621  Finisher
# 19978      32444    23444  September 30, 2023  2023  621  Finisher
# 19977      32444    23444  September 30, 2023  2023  620  Finisher
# 19989      32444    23444  September 30, 2023  2023  632  Finisher
# 19411      32444    23444  September 30, 2023  2023   54  Finisher
#
#                       Name Nationality Gender  Gender_Rank Age_Category  \
# 27220       jasha reynolds         USA      M         <NA>        45-49
# ...

# %%
master = pd.read_csv('../data/master/all_races_combined_master.csv')

# %%
master
# Out:
#        Series_ID  Race_ID                Date  Year Rank    Status  \
# 0           3753    37542      April 23, 2022  2022  DNF       DNF
# 1           3753    37542      April 23, 2022  2022  119  Finisher
# 2           3753    37542      April 23, 2022  2022  120  Finisher
# 3           3753    37542      April 23, 2022  2022  121  Finisher
# 4           3753    37542      April 23, 2022  2022  122  Finisher
# ...          ...      ...                 ...   ...  ...       ...
# 71075      32444    23444  September 30, 2023  2023  621  Finisher
# 71076      32444    23444  September 30, 2023  2023  621  Finisher
# 71077      32444    23444  September 30, 2023  2023  620  Finisher
# 71078      32444    23444  September 30, 2023  2023  632  Finisher
# 71079      32444    23444  September 30, 2023  2023   54  Finisher
#
#                       Name Nationality Gender  Gender_Rank Age_Category  \
# 0           jasha reynolds         USA      M          NaN        45-49
# ...

# %%
#### This correctly converted Date to datetime
master["Date"] = pd.to_datetime(
    master["Date"].str.replace(r"(\d+)(st|nd|rd|th)", r"\1", regex=True),
    errors="coerce"
)

# %%
master
# Out:
#        Series_ID  Race_ID       Date  Year Rank    Status  \
# 0           3753    37542 2022-04-23  2022  DNF       DNF
# 1           3753    37542 2022-04-23  2022  119  Finisher
# 2           3753    37542 2022-04-23  2022  120  Finisher
# 3           3753    37542 2022-04-23  2022  121  Finisher
# 4           3753    37542 2022-04-23  2022  122  Finisher
# ...          ...      ...        ...   ...  ...       ...
# 71075      32444    23444 2023-09-30  2023  621  Finisher
# 71076      32444    23444 2023-09-30  2023  621  Finisher
# 71077      32444    23444 2023-09-30  2023  620  Finisher
# 71078      32444    23444 2023-09-30  2023  632  Finisher
# 71079      32444    23444 2023-09-30  2023   54  Finisher
#
#                       Name Nationality Gender  Gender_Rank Age_Category  \
# 0           jasha reynolds         USA      M          NaN        45-49
# 1        rokas zickevicius         USA      M         82.0        20-34
# ...

# %%
print(master["Date"].dtype)
# Out:
# datetime64[ns]

# %%
master.drop(columns=["date_cleaned", "date_parsed"], inplace=True)

# %%
master
# Out:
#        Series_ID  Race_ID       Date  Year Rank    Status  \
# 0           3753    37542 2022-04-23  2022  DNF       DNF
# 1           3753    37542 2022-04-23  2022  119  Finisher
# 2           3753    37542 2022-04-23  2022  120  Finisher
# 3           3753    37542 2022-04-23  2022  121  Finisher
# 4           3753    37542 2022-04-23  2022  122  Finisher
# ...          ...      ...        ...   ...  ...       ...
# 71075      32444    23444 2023-09-30  2023  621  Finisher
# 71076      32444    23444 2023-09-30  2023  621  Finisher
# 71077      32444    23444 2023-09-30  2023  620  Finisher
# 71078      32444    23444 2023-09-30  2023  632  Finisher
# 71079      32444    23444 2023-09-30  2023   54  Finisher
#
#                       Name Nationality Gender  Gender_Rank Age_Category  \
# 0           jasha reynolds         USA      M          NaN        45-49
# 1        rokas zickevicius         USA      M         82.0        20-34
# ...

# %%
master_2021_2025 = master[master["Date"] >= "2021-01-01"]

# %%
master_2021_2025
# Out:
#        Series_ID  Race_ID       Date  Year Rank    Status  \
# 0           3753    37542 2022-04-23  2022  DNF       DNF
# 1           3753    37542 2022-04-23  2022  119  Finisher
# 2           3753    37542 2022-04-23  2022  120  Finisher
# 3           3753    37542 2022-04-23  2022  121  Finisher
# 4           3753    37542 2022-04-23  2022  122  Finisher
# ...          ...      ...        ...   ...  ...       ...
# 71075      32444    23444 2023-09-30  2023  621  Finisher
# 71076      32444    23444 2023-09-30  2023  621  Finisher
# 71077      32444    23444 2023-09-30  2023  620  Finisher
# 71078      32444    23444 2023-09-30  2023  632  Finisher
# 71079      32444    23444 2023-09-30  2023   54  Finisher
#
#                       Name Nationality Gender  Gender_Rank Age_Category  \
# 0           jasha reynolds         USA      M          NaN        45-49
# 1        rokas zickevicius         USA      M         82.0        20-34
# ...

# %%
master_2021_2025.to_csv('../data/master/master_2021_2025.csv', index = False)

# %%
import pandas as pd
import random

# %%
athlete_id = pd.read_csv('../data/master/golden_ticket_recipient_master_table.csv')

# %%
athlete_id
# Out:
#      Race_ID Gender  Ticket_Position               Name  Gender_Rank  WS_Year  \
# 0         22      M                1       jonathan rea            1     2022
# 1         22      M                2          tyler fox            2     2022
# 2         22      F                1     marianne hogan            1     2022
# 3         22      F                2         ellie pell            2     2022
# 4         23      M                1       jeffrey colt            1     2023
# ..       ...    ...              ...                ...          ...      ...
# 110    14221      F                2     camille bruyas            2     2022
# 111    14222      M                1  mathieu blanchard            2     2023
# 112    14222      M                2          tom evans            3     2023
# 113    14222      F                1       katie schide            1     2023
# 114    14222      F                2     eszter csillag            5     2023
#
#      WS_ID
# 0    87878
# ...

# %%
unique_names = athlete_id['Name'].unique()

# %%
athlete_ids = random.sample(range(100, 1000), len(unique_names))

# %%
athlete_id_map = dict(zip(unique_names, athlete_ids))

# %%
athlete_id['Athlete_ID'] = athlete_id['Name'].map(athlete_id_map)

# %%
athlete_id.tail(50)
# Out:
#      Race_ID Gender  Ticket_Position                Name  Gender_Rank  \
# 65     99186      M                2   blake slattengren            2
# 66     99186      F                1     heather jackson            1
# 67     99186      F                2        ragna debats            2
# 68    112165      M                1         david roche            1
# 69    112165      M                2       jeff mogavero            2
# 70    112165      F                1         riley brady            1
# 71    112165      F                2      hannah allgood            2
# 72    122877      M                1         will murray            1
# 73    122877      M                2     canyon woodward            3
# 74    122877      F                1          tara dower            1
# 75    122877      F                2         addie bracy            3
# 76     23444      M                1        jim walmsley            1
# ...

# %%
athlete_id.to_csv('../data/master/golden_ticket_recipient_table_with_athlete_ID.csv')

# %%
df = pd.read_csv("../data/raw/utmb_format/festival_des_templiers_100K_df_raw.csv")

# %%
# Step 1: Filter out DNFs only
df_finished = df[df['Status'].str.upper() != 'DNF'].copy()

# Step 2: Sort by Race_ID, Gender, and Time
df_finished = df_finished.sort_values(by=['Race_ID', 'Gender', 'Time'])

# Step 3: Assign Gender_Rank
df_finished['Gender_Rank'] = df_finished.groupby(['Race_ID', 'Gender']).cumcount() + 1

# Step 4: Merge back using Race_ID and Name
df = df.merge(
    df_finished[['Race_ID', 'Name', 'Gender', 'Time', 'Gender_Rank']],
    on=['Race_ID', 'Name', 'Gender', 'Time'],
    how='left'
)

# %%
df
# Out:
#        Series_ID  Race_ID   Race_Date    Year Rank    Status             Name  \
# 0          623.0  62321.0  10/22/2021  2021.0    1  Finisher     vincent viet
# 1          623.0  62321.0  10/22/2021  2021.0    2  Finisher  aurelien collet
# 2          623.0  62321.0  10/22/2021  2021.0    3  Finisher  clement desille
# 3          623.0  62321.0  10/22/2021  2021.0    4  Finisher  matthieu durand
# 4          623.0  62321.0  10/22/2021  2021.0    5  Finisher   romain olivier
# ...          ...      ...         ...     ...  ...       ...              ...
# 15961        NaN      NaN         NaN     NaN  NaN       NaN              NaN
# 15962        NaN      NaN         NaN     NaN  NaN       NaN              NaN
# 15963        NaN      NaN         NaN     NaN  NaN       NaN              NaN
# 15964        NaN      NaN         NaN     NaN  NaN       NaN              NaN
# 15965        NaN      NaN         NaN     NaN  NaN       NaN              NaN
#
# ...
