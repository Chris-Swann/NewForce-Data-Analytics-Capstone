# %% [markdown]
# # Create a Gender_Rank column to apply the correct gender rank (M, F) for filtering based on gender

# %%
import pandas as pd
import glob
import os

# %% [markdown]
# ### The following can be used for batch importing and concatenation. Used during initial joing of raw files.

# %%
# Set the folder path
folder_path = '../data/raw/utmb_format'

# Find all CSV files in the folder
csv_files_utmb_format = glob.glob(os.path.join(folder_path, '*.csv'))

# Read and combine all CSVs
df_list = []
for file in csv_files_utmb_format:
    temp_df = pd.read_csv(file)
    df_list.append(temp_df)

# Combine into one DataFrame
combined_df = pd.concat(df_list, ignore_index=True)

# %% [markdown]
# ### Import a singular raw file that needs to be concatenated with the combined master dataset

# %%
combined_df = pd.read_csv("../data/raw/utmb_format/festival_des_templiers_100K_df_raw.csv", encoding = 'utf-8')

# %%
combined_df.head()
# Out:
#    Series_ID  Race_ID   Race_Date  Year Rank    Status             Name  \
# 0        623    62321  2021-10-22  2021    1  Finisher     vincent viet
# 1        623    62321  2021-10-22  2021    2  Finisher  aurelien collet
# 2        623    62321  2021-10-22  2021    3  Finisher  clement desille
# 3        623    62321  2021-10-22  2021    4  Finisher  matthieu durand
# 4        623    62321  2021-10-22  2021    5  Finisher   romain olivier
#
#   Nationality Gender Age_Category      Time                    Race_Name  \
# 0         FRA      M        35-39  10:52:25  Festival des Templiers 100K
# 1         FRA      M        40-44  11:03:54  Festival des Templiers 100K
# 2         FRA      M        20-34  11:28:34  Festival des Templiers 100K
# 3         FRA      M        20-34  11:30:12  Festival des Templiers 100K
# 4         FRA      M        35-39  11:30:18  Festival des Templiers 100K
#
#          Race_Loc Race_Dist
# 0  Millau, France      100K
# 1  Millau, France      100K
# 2  Millau, France      100K
# 3  Millau, France      100K
# 4  Millau, France      100K

# %% [markdown]
# ### Temporarily remove DNFs, sort_values, assign Gender_Rank, merge back to the original dataset

# %%
# Filter out DNFs only
df_finished = combined_df[combined_df['Status'].str.upper() != 'DNF'].copy()

# Sort by Race_ID, Gender, and Time
df_finished = df_finished.sort_values(by=['Race_ID', 'Gender', 'Time'])

# Assign Gender_Rank
df_finished['Gender_Rank'] = df_finished.groupby(['Race_ID', 'Gender']).cumcount() + 1

# Step 4: Merge back using Race_ID and Name
df = combined_df.merge(
    df_finished[['Race_ID', 'Name', 'Gender', 'Time', 'Gender_Rank']],
    on=['Race_ID', 'Name', 'Gender', 'Time'],
    how='left'
)

# %%
df.shape
# Out:
# (5942, 15)

# %% [markdown]
# ### Combined master dataset uses 3 letter codes for countries. The following is a dictionary to map countries to their 3 letter code.

# %%
country_to_code = {
    'USA': 'USA',
    'POLAND': 'POL',
    'FRA': 'FRA',
    'FRANCE': 'FRA',
    'UNITED KINGDOM': 'GBR',
    'ICELAND': 'ISL',
    'SPAIN': 'ESP',
    'SWITZERLAND': 'CHE',
    'IRELAND': 'IRL',
    'ITALY': 'ITA',
    'LATVIA': 'LVA',
    'SOUTH AFRICA': 'ZAF',
    'MOROCCO': 'MAR',
    'LUXEMBOURG': 'LUX',
    'CHINA': 'CHN',
    'VENEZUELA': 'VEN',
    'JAPAN': 'JPN',
    'PORTUGAL': 'PRT',
    'MAURITIUS': 'MUS',
    'NEW ZEALAND': 'NZL',
    'SWEDEN': 'SWE',
    'ARGENTINA': 'ARG',
    'SLOVAKIA': 'SVK',
    'GERMANY': 'DEU',
    'ALGERIA': 'DZA',
    'AUSTRALIA': 'AUS',
    'CAMBODIA': 'KHM',
    'NORWAY': 'NOR',
    'CROATIA': 'HRV',
    'MEXICO': 'MEX',
    'COLOMBIA': 'COL',
    'CANADA': 'CAN',
    'NETHERLANDS': 'NLD',
    'BRAZIL': 'BRA',
    'TÜRKIYE': 'TUR',
    'BELGIUM': 'BEL',
    'CHILE': 'CHL',
    'SOUTH KOREA': 'KOR',
    'DENMARK': 'DNK',
    'RUSSIA': 'RUS',
    'SLOVENIA': 'SVN',
    'UKRAINE': 'UKR',
    'SERBIA': 'SRB',
    'HUNGARY': 'HUN',
    'ROMANIA': 'ROU',
    'URUGUAY': 'URY',
    'ANDORRA': 'AND',
    'ECUADOR': 'ECU',
    'FINLAND': 'FIN',
    'HONG KONG, CHINA': 'HKG',
    'BELARUS': 'BLR',
    'SINGAPORE': 'SGP',
    'CZECH REPUBLIC': 'CZE',
    'BULGARIA': 'BGR',
    'PERU': 'PER',
    'GREECE': 'GRC',
    'PHILIPPINES': 'PHL',
    'LITHUANIA': 'LTU',
    'MALTA': 'MLT',
    'BOSNIA AND HERZEGOVINA': 'BIH',
    'THAILAND': 'THA',
    'AUSTRIA': 'AUT',
    'ESTONIA': 'EST',
    'CHINESE TAIPEI': 'TWN',
    'INDONESIA': 'IDN',
    'VIETNAM': 'VNM',
    'INDIA': 'IND',
    'MALAYSIA': 'MYS',
    'COSTA RICA': 'CRI',
    'ISRAEL': 'ISR',
    'SAUDI ARABIA': 'SAU',
    'NIGER': 'NER',
    'MOLDOVA': 'MDA',
    'EGYPT': 'EGY',
    'MONTENEGRO': 'MNE',
    'KOSOVO': 'XKX',
    'IRAN': 'IRN',
    'EL SALVADOR': 'SLV',
    'LEBANON': 'LBN',
    'PARAGUAY': 'PRY',
    'PUERTO RICO': 'PRI',
    'OMAN': 'OMN',
    'ALBANIA': 'ALB',
    'BENIN': 'BEN',
    'NORTH MACEDONIA (REPUBLIC OF)': 'MKD',
    'TUNISIA': 'TUN',
    'NEPAL': 'NPL',
    'QATAR': 'QAT',
    'DOMINICAN REPUBLIC': 'DOM',
    'SAN MARINO': 'SMR',
    'NICARAGUA': 'NIC',
    'GUATEMALA': 'GTM',
    'GAMBIA': 'GMB',
    'MONACO': 'MCO',
    'KYRGYZSTAN': 'KGZ',
    'KENYA': 'KEN',
    'BOLIVIA': 'BOL',
    'BAHRAIN': 'BHR',
    'MACAO, CHINA': 'MAC',
    'TOGO': 'TGO',
    'CYPRUS': 'CYP',
    'KUWAIT': 'KWT',
    'NAMIBIA': 'NAM',
    'ZIMBABWE': 'ZWE',
    'UGANDA': 'UGA',
    'LIECHTENSTEIN': 'LIE',
    'HAITI': 'HTI',
    'SWAZILAND': 'SWZ',
    'MONGOLIA': 'MNG',
    'CAMEROON': 'CMR',
    'KAZAKHSTAN': 'KAZ',
    'NEUTRAL ATHLETE': None,
    'UNITED ARAB EMIRATES': 'ARE',
    'MADAGASCAR': 'MDG',
    'AFGHANISTAN': 'AFG',
    'HONDURAS': 'HND',
    'GEORGIA': 'GEO',
    'JORDAN': 'JOR',
    'AZERBAIJAN': 'AZE',
    'BANGLADESH': 'BGD',
    'SENEGAL': 'SEN',
    'BRUNEI': 'BRN',
    'KINGDOM': None,
    'ZEALAND': None,
    'KOREA': None,
    'AMERICA': None,
    'TAIPEI': None,
    'AFRICA': None,
    'ATHLETE': None,
    'SAO TOME AND PRINCIPE': 'STP',
    'PANAMA': 'PAN',
    'CONGO': 'COG',
    'JAMAICA': 'JAM',
    'FRENCH POLYNESIA': 'PYF',
    'IRAQ': 'IRQ',
    'UZBEKISTAN': 'UZB',
    'PAKISTAN': 'PAK',
    'NORTHERN MARIANA ISLANDS': 'MNP',
    'SOUTH SUDAN': 'SSD',
    'ARMENIA': 'ARM',
    'BOTSWANA': 'BWA',
    'BAHAMAS': 'BHS',
    'NORTH KOREA': 'PRK',
    'VANUATU': 'VUT'
}

# %%
df['Nationality'] = df['Nationality'].map(country_to_code_cleaned)

# %%
df.tail()
# Out:
# (5942, 15)

# %%
df.shape
# Out:
# (5942, 16)

# %%
# df.to_csv("../data/raw/utmb_format/festival_des_templiers_100K_df_raw.csv", index = False, encoding = 'utf-8')

# %% [markdown]
# # Import the new dataset and master dataset. Clean the columns to ensure clean merging. Additional cleaning on 'Rank' and converting 'Race_Date' to datetime for sorting.

# %%
# df_new = pd.read_csv('../data/raw/utmb_format/festival_des_templiers_100K_df_raw.csv', encoding='utf-8')
# df_master = pd.read_csv('../data/master/master_cleaned/all_combined_races_master_2021_2025_exclude_western_states.csv', encoding='utf-8')

# %%
df_new.columns = df_new.columns.str.strip()
df_master.columns = df_master.columns.str.strip()

# %%
df_merged = pd.concat([df_master, df_new], ignore_index=True)

# %%
df_merged.shape
# Out:
# (50108, 15)

# %%
df_merged['Rank'] = df_merged['Rank'].replace('0', 'DNF')

# %%
df_merged.shape
# Out:
# (50108, 15)

# %%
df_merged['Race_Date'] = pd.to_datetime(df_merged['Race_Date'])

# %%
df_merged.shape
# Out:
# (61992, 16)

# %%
# df_merged.to_csv('../data/master/master_cleaned/all_combined_races_master_2021_2025_exclude_western_states.csv', index = False, encoding='utf-8')

# %%
df_master = pd.read_csv('../data/master/master_cleaned/all_combined_races_master_2021_2025_exclude_western_states.csv', encoding='utf-8')

# %%
df_master.shape
# Out:
# (56050, 15)

# %% [markdown]
# # Fixing F-UP

# %%
df = df.drop(columns=['Gender_Rank'], errors='ignore')

# %%
# Step 0: Create a unique row ID
df = df.reset_index().rename(columns={'index': 'Row_ID'})

# %%
# Step 1: Convert Time to timedelta
df['Time'] = pd.to_timedelta(df['Time'], errors='coerce')

# Step 2: Filter finishers with valid times
df_finishers = df[(df['Status'] == 'Finisher') & df['Time'].notna()].copy()

# Step 3: Assign Gender Rank within each race
df_finishers['Gender_Rank'] = (
    df_finishers.groupby(['Race_ID', 'Gender'])['Time'].rank(method='min')
)

# Step 4: Merge back using Row_ID to avoid duplication
df = df.drop(columns=['Gender_Rank'], errors='ignore')
df = df.merge(
    df_finishers[['Row_ID', 'Gender_Rank']],
    on='Row_ID',
    how='left'
)

# Optional: Drop Row_ID if you don't need it
df = df.drop(columns='Row_ID')

# %%
df.shape
# Out:
# (50108, 15)

# %%
def format_timedelta(td):
    if pd.isna(td):
        return ''
    total_seconds = int(td.total_seconds())
    hours = total_seconds // 3600
    minutes = (total_seconds % 3600) // 60
    seconds = total_seconds % 60
    return f"{hours:02}:{minutes:02}:{seconds
# 8       Tarawera 100K  Rotorua, New Zealand      100K          2.0
# 9       Tarawera 100K  Rotorua, New Zealand      100K          6.0
# 10  Black Canyon 100K             Mayer, AZ      100K          7.0
# 11  Black Canyon 100K             Mayer, AZ      100K         32.0
# 12  Black Canyon 100K             Mayer, AZ      100K         33.0
# 13  Black Canyon 100K             Mayer, AZ      100K          8.0
# 14  Black Canyon 100K             Mayer, AZ      100K         34.0
# 15  Black Canyon 100K             Mayer, AZ      100K         35.0
# 16      Tarawera 100K  Rotorua, New Zealand      100K          7.0
# 17  Black Canyon 100K             Mayer, AZ      100K         36.0
# 18  Black Canyon 100K             Mayer, AZ      100K         37.0
# 19  Black Canyon 100K             Mayer, AZ      100K         38.0
# 20  Black Canyon 100K             Mayer, AZ      100K          9.0
# 21  Black Canyon 100K             Mayer, AZ      100K         39.0
# 22  Black Canyon 100K             Mayer, AZ      100K         40.0
# 23  Black Canyon 100K             Mayer, AZ      100K         10.0
# 24  Black Canyon 100K             Mayer, AZ      100K         41.0
# 25      Tarawera 100K  Rotorua, New Zealand      100K          8.0
# 26  Black Canyon 100K             Mayer, AZ      100K         42.0
# 27  Black Canyon 100K             Mayer, AZ      100K         43.0
# 28  Black Canyon 100K             Mayer, AZ      100K         11.0
# 29  Black Canyon 100K             Mayer, AZ      100K         12.0
# 30      Tarawera 100K  Rotorua, New Zealand      100K          9.0
# 31  Black Canyon 100K             Mayer, AZ      100K         13.0
# 32  Black Canyon 100K             Mayer, AZ      100K         44.0
# 33      Tarawera 100K  Rotorua, New Zealand      100K         10.0
# 34      Tarawera 100K  Rotorua, New Zealand      100K          3.0
# 35  Black Canyon 100K             Mayer, AZ      100K         45.0
# 36  Black Canyon 100K             Mayer, AZ      100K         46.0
# 37  Black Canyon 100K             Mayer, AZ      100K         14.0
# 38  Black Canyon 100K             Mayer, AZ      100K         47.0
# 39  Black Canyon 100K             Mayer, AZ      100K         48.0
# 40  Black Canyon 100K             Mayer, AZ      100K         49.0
# 41  Black Canyon 100K             Mayer, AZ      100K         50.0
# 42  Black Canyon 100K             Mayer, AZ      100K         51.0
# 43  Black Canyon 100K             Mayer, AZ      100K         15.0
# 44  Black Canyon 100K             Mayer, AZ      100K         52.0
# 45      Tarawera 100K  Rotorua, New Zealand      100K         11.0
# 46  Black Canyon 100K             Mayer, AZ      100K         53.0
# 47  Black Canyon 100K             Mayer, AZ      100K         54.0
# 48  Black Canyon 100K             Mayer, AZ      100K         55.0
# 49  Black Canyon 100K             Mayer, AZ      100K         56.0

# %%
df.to_csv('../data/master/master_cleaned/all_combined_races_master_2021_2025_exclude_western_states_test_test_test.csv', index = False, encoding='utf-8')

# %%
df.shape
# Out:
# (50108, 15)

# %% [markdown]
# # Fixing big F-UP: Duplication on Festival des templiers

# %%
race_ids_to_remove = [62321,62322,62323,62324,62325]

# %%
df_master_cleaned = df_master[~df_master['Race_ID'].isin(race_ids_to_remove)]

# %%
df_master_cleaned.shape
# Out:
# (44166, 15)

# %%
# df.to_csv('../data/master/master_cleaned/all_combined_races_master_2021_2025_exclude_western_states.csv', index = False, encoding='utf-8')
